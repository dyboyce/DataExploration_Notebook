# %% [markdown]
# # Data Exploration

# %% [markdown]
# # Steps Taken
# 1. Download full dataset
# 2. Create ER diagram of relationships
# 3. Attempt to normalize
# 4. Hypothesis of Analytics to do after ETL is done.

# %% [markdown]
# # Download:
# This is a fixed dataset, but will be expanded later due to the nature of the project. The full download is about 30.8 GB unpacked on disk.
# When I explain this will be expanded, meaning the final project will be adapted into a pipeline that can take any video, then annotate it with best AI guesses, and draw those objects onto the videos.
# This will mean a less ridgid relational database, and will need a less strict schema. The trade-off down the road would be to hopefully be able to draw more analytics from the less defined broad guesses on more things rather than the normal set.

# %% [markdown]
# # ER Diagram
# This was simple, there are many different videos, but they all fall back to the same type of setup with Objects, the Events, which denote a complicated happening and can contain many objects interacting, the mapping between the two, and the invdividual list of frames.
# ![Virat_EDA.jpg](attachment:Virat_EDA.jpg)

# %% [markdown]
# # Normalization
# Much of the data is very repetitive, but since it repeats frame by frame, it is hard to condense rows into their events without data loss. The best we could do without creating boxes table for each object/event is to break their repetitive box data out into a table that contains all the coordinates.
# See below:

# %% [markdown]
# ![Virat_EDA_Norm.jpg](attachment:Virat_EDA_Norm.jpg)

# %% [markdown]
# ## Future Schema
# At this point, we have not finalized the storage options we have for this. Am working on it with the mentor.
# But as stated befor this is not the final form of the database. The final result will be much less structured but hopefully open to more analytics done on events, boxes, movement of objects within those.
# This would open up the value of data to a much wider pool than just these set security cams, but this will also mean a more Warehouse-ish style storage to keep the utility high.

# %% [markdown]
# # Final Note
# At this point in the course I am focused on course progression as per my mentor, and we have not nailed down all the specifics of Atthe capstone's end form. Once I make sure I have good progress, we will go forward on the project.
